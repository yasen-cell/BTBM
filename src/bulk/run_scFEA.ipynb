# %% [markdown]
# This example runs scFEA on bulk data using the complete human metabolic modules.
#
# **Parameters:**
#
# - `--data_dir`: Directory containing scFEA model files.
# - `--input_dir`: Directory containing input data.
# - `--test_file`: Input bulk_data file (e.g., TNBC, MTC84, NCI60, or ccRCC), where rows are genes and columns are samples.
# - `--moduleGene_file`: `module_gene_m168.csv`; contains genes for each module.
# - `--stoichiometry_matrix`: `cmMat_c70_m168.csv`; describes the relationship between compounds and modules. Each row is an intermediate metabolite, and each column is a metabolic module.
# - `--cName_file`: `cName_c70_m168.csv`; The name of compounds. The table contains two rows. First row is compounds name and second row is corresponding id.

# %%
# %%bash
# cd /scFEA
# python src/scFEA.py --data_dir data --input_dir input \
#                     --test_file bulk_data.csv \
#                     --moduleGene_file module_gene_m168.csv \
#                     --stoichiometry_matrix cmMat_c70_m168.csv \
#                     --cName_file cName_c70_m168.csv
